# %%
import pandas as pd
df=pd.read_csv("/home/fansan/Desktop/data1.csv")
df
# Out:
#       Name  Package(in Lakhs)
# 0   Deepak               22.0
# 1     Amit                NaN
# 2   Sudeep               25.0
# 3  Pratham               32.0
# 4    Arpit                NaN
# 5    Sudha               42.0

# %%
df.sort_values(df.columns[1],ascending=False)
# Out:
#       Name  Package(in Lakhs)
# 5    Sudha               42.0
# 3  Pratham               32.0
# 2   Sudeep               25.0
# 0   Deepak               22.0
# 1     Amit                NaN
# 4    Arpit                NaN

# %%
df.fillna(0)
# Out:
#       Name  Package(in Lakhs)
# 0   Deepak               22.0
# 1     Amit                0.0
# 2   Sudeep               25.0
# 3  Pratham               32.0
# 4    Arpit                0.0
# 5    Sudha               42.0

# %%
df.fillna(0)
# Out:
#       Name  Package(in Lakhs)
# 0   Deepak               22.0
# 1     Amit                0.0
# 2   Sudeep               25.0
# 3  Pratham               32.0
# 4    Arpit                0.0
# 5    Sudha               42.0

# %%
df.fillna(df.mean())
# Out:
# /tmp/ipykernel_5990/634187881.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean())
#       Name  Package(in Lakhs)
# 0   Deepak              22.00
# 1     Amit              30.25
# 2   Sudeep              25.00
# 3  Pratham              32.00
# 4    Arpit              30.25
# 5    Sudha              42.00
