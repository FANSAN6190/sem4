# %%
import pandas as pd
df=pd.read_csv("/home/fansan/Desktop/data1.csv")
df
# Out:
#       Name  Package(in Lakhs)
# 0   Deepak               22.0
# 1     Amit                NaN
# 2   Sudeep               25.0
# 3  Pratham               32.0
# 4    Arpit                NaN
# 5    Sudha               42.0

# %%
df.sort_values(df.columns[1],ascending=False)
# Out:
#       Name  Package(in Lakhs)
# 5    Sudha               42.0
# 3  Pratham               32.0
# 2   Sudeep               25.0
# 0   Deepak               22.0
# 1     Amit                NaN
# 4    Arpit                NaN

# %%
df.fillna(0)
# Out:
#       Name  Package(in Lakhs)
# 0   Deepak               22.0
# 1     Amit                0.0
# 2   Sudeep               25.0
# 3  Pratham               32.0
# 4    Arpit                0.0
# 5    Sudha               42.0

# %%
df.fillna(0)
# Out:
#       Name  Package(in Lakhs)
# 0   Deepak               22.0
# 1     Amit                0.0
# 2   Sudeep               25.0
# 3  Pratham               32.0
# 4    Arpit                0.0
# 5    Sudha               42.0

# %%
df.fillna(df.mean)
# Out:
#       Name                                  Package(in Lakhs)
# 0   Deepak                                               22.0
# 1     Amit  <bound method NDFrame._add_numeric_operations....
# 2   Sudeep                                               25.0
# 3  Pratham                                               32.0
# 4    Arpit  <bound method NDFrame._add_numeric_operations....
# 5    Sudha                                               42.0
